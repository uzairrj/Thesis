# %%
# %cp /content/drive/MyDrive/Trajectron.zip -d /content/

# %%
# !unzip /content/Trajectron.zip -d /content/

# %%
# %cd /content/content/Trajectron/
# Out:
# /content/content/Trajectron

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 12.7 MB/s eta 0:00:00
# ...
#   Created wheel for attrdict: filename=attrdict-2.0.0-py2.py3-none-any.whl size=9987 sha256=8d3065223c81b73bdc82de24f6c7ca26f5d1f3aaa846600932bb86eb88fc3ed3
#   Stored in directory: /root/.cache/pip/wheels/f1/07/58/b0b3eafd341dce5eba1638698709a2f807492c5dea0ea827a9
# Successfully built attrdict
# ...

# %%
# %cd code/
# Out:
# /content/content/Trajectron/code

# %%
# !python train.py --data_dir /content/content/Trajectron/sgan-dataset/data --train_data_dict indoor_train.pkl --eval_data_dict indoor_test.pkl
# Out:
# -----------------------
# | TRAINING PARAMETERS |
# -----------------------
# | batch_size: 64
# | batch_multiplier: 1
# | effective batch size: 64 (= 64 * 1)
# | device: cuda:0
# | eval_device: cuda:0
# | max_speed: 100.0
# | edge_radius: 6.56168
# | EE state_combine_method: sum
# | EIE scheme: attention
# | dynamic_edges: yes
# | robot node: False
# | edge_addition_filter: [0.25, 0.5, 1.0]
# | edge_removal_filter: [1.0, 0.5, 0.25]
# | MHL: 8
# | PH: 12
# -----------------------
# Loaded training data from /content/content/Trajectron/sgan-dataset/data/indoor_train.pkl, train_dt = 0.40
# Loaded evaluation data from /content/content/Trajectron/sgan-dataset/data/indoor_test.pkl, eval_dt = 0.40
# Created training STG model.
# Created evaluation STG model.
# Created aggregate training scene graph.
# Computed edge scaling for the training scene graph.
# Created aggregate evaluation scene graph.
# Computed edge scaling for the evaluation scene graph.
#
# ...

# %%
# %cd /content/content/
# Out:
# /content/content

# %%
# %ls
# Out:
# Trajectron/

# %%
# !zip -r Trajectron.zip Trajectron/
# Out:
#   adding: Trajectron/ (stored 0%)
#   adding: Trajectron/sgan-dataset/ (stored 0%)
#   adding: Trajectron/sgan-dataset/format_data.py (deflated 75%)
#   adding: Trajectron/sgan-dataset/val/ (stored 0%)
#   adding: Trajectron/sgan-dataset/val/val_data.txt (deflated 70%)
#   adding: Trajectron/sgan-dataset/Result Analyses.ipynb (deflated 33%)
#   adding: Trajectron/sgan-dataset/.gitignore (stored 0%)
#   adding: Trajectron/sgan-dataset/test/ (stored 0%)
#   adding: Trajectron/sgan-dataset/test/test_data.txt (deflated 71%)
#   adding: Trajectron/sgan-dataset/Qualitative Plots.ipynb (deflated 27%)
#   adding: Trajectron/sgan-dataset/data/ (stored 0%)
#   adding: Trajectron/sgan-dataset/data/hotel_test.pkl (deflated 97%)
#   adding: Trajectron/sgan-dataset/data/indoor/ (stored 0%)
#   adding: Trajectron/sgan-dataset/data/indoor/.ipynb_checkpoints/ (stored 0%)
#   adding: Trajectron/sgan-dataset/data/indoor/val/ (stored 0%)
# ...

# %%
# %cd /content/content/Trajectron/code
# Out:
# /content/content/Trajectron/code

# %%
# !python test_online.py --trained_model_dir /content/content/Trajectron/code/debug/logs/models_07_May_2023_15_30_15 --data_dir /content/content/Trajectron/sgan-dataset/data --test_data_dict indoor_test.pkl
# Out:
# 485.55 MBs of RAM initially used.
#
# Loading from /content/content/Trajectron/code/debug/logs/models_07_May_2023_15_30_15/model_registrar-1999.pt
# Loaded!
#
# Looking at the indoor sequence, data_id 1
# At t=0, have 1 nodes, 0 edges which uses 4.67 MBs of RAM.
# t=1: took 0.18 s (= 5.43 Hz) w/ MSE 0.99 and FSE 2.89 and 1 nodes, 0 edges uses 20.58 MBs of RAM.
# t=2: took 0.02 s (= 63.06 Hz) w/ MSE 1.41 and FSE 4.46 and 1 nodes, 0 edges uses 20.58 MBs of RAM.
# t=3: took 0.02 s (= 47.14 Hz) w/ MSE 1.84 and FSE 5.29 and 1 nodes, 0 edges uses 20.58 MBs of RAM.
# t=4: took 0.01 s (= 71.16 Hz) w/ MSE 2.21 and FSE 5.99 and 1 nodes, 0 edges uses 20.58 MBs of RAM.
# t=5: took 0.01 s (= 71.98 Hz) w/ MSE 3.09 and FSE 7.55 and 1 nodes, 0 edges uses 20.58 MBs of RAM.
# t=6: took 0.01 s (= 73.42 Hz) w/ MSE 3.95 and FSE 8.67 and 1 nodes, 0 edges uses 20.58 MBs of RAM.
# t=7: took 0.02 s (= 59.03 Hz) w/ MSE 3.18 and FSE 6.65 and 1 nodes, 0 edges uses 20.58 MBs of RAM.
# ...
