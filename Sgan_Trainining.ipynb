# %%
# !unzip sgan_master.zip
# Out:
# Archive:  sgan_master.zip
#    creating: sgan_master/datasets/
#    creating: sgan_master/datasets/indoor/
#    creating: sgan_master/datasets/indoor/test/
#   inflating: sgan_master/datasets/indoor/test/test_data.txt
#    creating: sgan_master/datasets/indoor/train/
#   inflating: sgan_master/datasets/indoor/train/train_data.txt
#    creating: sgan_master/datasets/indoor/val/
#   inflating: sgan_master/datasets/indoor/val/val_data.txt
#    creating: sgan_master/images/
#   inflating: sgan_master/images/2.gif
#   inflating: sgan_master/images/3.gif
#   inflating: sgan_master/images/model.png
#   inflating: sgan_master/LICENSE
#   inflating: sgan_master/MODEL_ZOO.md
#   inflating: sgan_master/README.md
#   inflating: sgan_master/requirements.txt
#    creating: sgan_master/scripts/
#   inflating: sgan_master/scripts/download_data.sh
#   inflating: sgan_master/scripts/download_models.sh
#   inflating: sgan_master/scripts/evaluate_model.py
# ...

# %%
# %cd sgan_master/
# Out:
# /content/sgan_master

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 75.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.4/37.4 MB 31.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for attrdict: filename=attrdict-2.0.0-py2.py3-none-any.whl size=9987 sha256=dd7128c882875e36393dcb1494dbf8511ce90ce08feba375f7c0ce6ad7a59c04
#   Stored in directory: /root/.cache/pip/wheels/fe/ab/f3/a4b735d7357585a8d3285377f3bbde7f88a5b10b8ded4e0a9a
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
# ...

# %%
# !python scripts/train.py
# Out:
# [INFO: train.py:  122]: Initializing train dataset
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [INFO: train.py:  124]: Initializing val dataset
# [INFO: train.py:  131]: There are 13.578125 iterations per epoch
# [INFO: train.py:  156]: Here is the generator:
# [INFO: train.py:  157]: TrajectoryGenerator(
#   (encoder): Encoder(
#     (encoder): LSTM(64, 64)
#     (spatial_embedding): Linear(in_features=2, out_features=64, bias=True)
#   )
#   (decoder): Decoder(
#     (decoder): LSTM(64, 128)
#     (pool_net): PoolHiddenNet(
# ...

# %%
# !bash /content/sgan_master/scripts/download_data.sh
# Out:
# --2023-04-30 12:00:03--  https://www.dropbox.com/s/8n02xqv3l9q18r1/datasets.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/8n02xqv3l9q18r1/datasets.zip [following]
# --2023-04-30 12:00:04--  https://www.dropbox.com/s/raw/8n02xqv3l9q18r1/datasets.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc25720e9acbd1a257337b076b0f.dl.dropboxusercontent.com/cd/0/inline/B7L8Y7KzHIyKBUu9b6WnTTY3oKXd3iTmroIsUNAjWxLH9CHygfGJ-b6MHFeg-qji2iWzu-40OPEOwM66wxT-cUuDPdaaU8haBMz6qJMoXMBPCDjtnsuBcM9fcnNIvZtRT7QY_zttG9R2QVVexzSm8CvtilQrW6HKR7bUiZlaY_zLsQ/file# [following]
# ...

# %%
# !python scripts/train.py --dataset_name indoor --loader_num_workers 2
# Out:
# [INFO: train.py:  122]: Initializing train dataset
# [INFO: train.py:  124]: Initializing val dataset
# [INFO: train.py:  131]: There are 37.96875 iterations per epoch
# [INFO: train.py:  156]: Here is the generator:
# [INFO: train.py:  157]: TrajectoryGenerator(
#   (encoder): Encoder(
#     (encoder): LSTM(64, 64)
#     (spatial_embedding): Linear(in_features=2, out_features=64, bias=True)
#   )
#   (decoder): Decoder(
#     (decoder): LSTM(64, 128)
#     (pool_net): PoolHiddenNet(
#       (spatial_embedding): Linear(in_features=2, out_features=64, bias=True)
#       (mlp_pre_pool): Sequential(
#         (0): Linear(in_features=192, out_features=512, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=512, out_features=1024, bias=True)
#         (3): ReLU()
#       )
#     )
#     (mlp): Sequential(
#       (0): Linear(in_features=1152, out_features=1024, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=1024, out_features=128, bias=True)
# ...

# %%
# !bash ./scripts/run_traj.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# [INFO: train.py:  338]: Saving checkpoint to /content/sgan_master/gan_test_with_model.pt
# [INFO: train.py:  340]: Done.
# [INFO: train.py:  346]: Saving checkpoint to /content/sgan_master/gan_test_no_model.pt
# [INFO: train.py:  357]: Done.
# [INFO: train.py:  236]: Starting epoch 223
# [INFO: train.py:  281]: t = 11101 / 37968
# [INFO: train.py:  283]:   [D] D_data_loss: 1.369
# [INFO: train.py:  283]:   [D] D_total_loss: 1.369
# [INFO: train.py:  286]:   [G] G_discriminator_loss: 0.693
# [INFO: train.py:  286]:   [G] G_l2_loss_rel: 20.543
# [INFO: train.py:  286]:   [G] G_total_loss: 21.236
# [INFO: train.py:  297]: Checking stats on val ...
# [INFO: train.py:  301]: Checking stats on train ...
# [INFO: train.py:  308]:   [val] ade: 4.216
# [INFO: train.py:  308]:   [val] ade_l: 0.000
# [INFO: train.py:  308]:   [val] ade_nl: 4.216
# [INFO: train.py:  308]:   [val] d_loss: 0.916
# [INFO: train.py:  308]:   [val] fde: 7.607
# ...

# %%
# !zip -r myzip myzip.zip /content/sgan_master
# Out:
#   adding: content/sgan_master/ (stored 0%)
#   adding: content/sgan_master/TRAINING.md (deflated 64%)
#   adding: content/sgan_master/scripts/ (stored 0%)
#   adding: content/sgan_master/scripts/download_models.sh (deflated 23%)
#   adding: content/sgan_master/scripts/train.py (deflated 79%)
#   adding: content/sgan_master/scripts/evaluate_model.py (deflated 69%)
#   adding: content/sgan_master/scripts/print_args.py (deflated 40%)
#   adding: content/sgan_master/scripts/download_data.sh (deflated 26%)
#   adding: content/sgan_master/scripts/run_traj.sh (deflated 56%)
#   adding: content/sgan_master/requirements.txt (deflated 7%)
#   adding: content/sgan_master/images/ (stored 0%)
#   adding: content/sgan_master/images/2.gif (deflated 10%)
#   adding: content/sgan_master/images/model.png (deflated 12%)
#   adding: content/sgan_master/images/3.gif (deflated 11%)
#   adding: content/sgan_master/gan_test_no_model.pt (deflated 54%)
# ...

# %%
# !unzip sgan_master.zip
# Out:
# Archive:  sgan_master.zip
#   inflating: sgan_master/checkpoint_no_model.pt
#   inflating: sgan_master/checkpoint_with_model.pt
#    creating: sgan_master/datasets/
#    creating: sgan_master/datasets/eth/
#    creating: sgan_master/datasets/eth/test/
#   inflating: sgan_master/datasets/eth/test/biwi_eth.txt
#    creating: sgan_master/datasets/eth/train/
#   inflating: sgan_master/datasets/eth/train/biwi_hotel_train.txt
#   inflating: sgan_master/datasets/eth/train/crowds_zara01_train.txt
#   inflating: sgan_master/datasets/eth/train/crowds_zara02_train.txt
#   inflating: sgan_master/datasets/eth/train/crowds_zara03_train.txt
#   inflating: sgan_master/datasets/eth/train/students001_train.txt
#   inflating: sgan_master/datasets/eth/train/students003_train.txt
#   inflating: sgan_master/datasets/eth/train/uni_examples_train.txt
#    creating: sgan_master/datasets/eth/val/
#   inflating: sgan_master/datasets/eth/val/biwi_hotel_val.txt
# ...

# %%
# !pip install attrdict==2.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached attrdict-2.0.0-py2.py3-none-any.whl
# ...

# %%
# !python /content/sgan_master/scripts/evaluate_model.py --model_path /content/sgan_master/checkpoint_with_model.pt
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Dataset: indoor, Pred Len: 8, ADE: 5.20, FDE: 10.10

# %%
# !pip show attrdict
# Out:
# Name: attrdict
# Version: 2.0.0
# Summary: A dict with attribute-style access
# Home-page: https://github.com/bcj/AttrDict
# Author: Brendan Curran-Johnson
# Author-email: brendan@bcjbcj.ca
# License: MIT License
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: six
# Required-by:
